# %% [markdown]
# # Tasca 3: Estructura de control
#
# ## Descripció:
# Comencem a familiaritzar-nos amb les estructures de control de Python
#
# ### Nivell 1
#
# * Exercici 1 :
# L'exercici consisteix a crear un programa que et classifiqui una variable numèrica en funció de l’escala Suspès/Aprovat/Notable/Excel·lent.

# %%
# Python program to classify a numeric value in a label
print("\n Program to label a numeric value with a classification system")
# import module
#from pconst import const
import constant

# Creating a List with the labels
# Lists are just like the arrays, declared in other languages which is a ordered
# collection of data. It is very flexible as the items in a list do not need to be
# of the same type.
# Creating List
# Lists in Python can be created by just placing the sequence inside the square brackets[].
scale_list = ["Suspès", "Aprovat", "Notable", "Excel·lent"]
# Accessing elements of List
# In order to access the list items refer to the index number. Use the index operator [ ] # to access an item in a list. In Python, negative sequence indexes represent positions
# from the end of the array.

# Creating a Tuple
# tuple is also an ordered collection of Python objects. The only difference
# between type and list is that tuples are immutable i.e. tuples cannot be
# modified after it is created.
# Creating Tuple
# tuples are created by placing a sequence of values separated by ‘comma’ with or
# without the use of parentheses for grouping of the data sequence. Tuples can
# contain any number of elements and of any datatype (like strings, integers, list, etc.).
scale_tuple = tuple(["Suspès", "Aprovat", "Notable", "Excel·lent"])
# Accessing elements of Tuple
# In order to access the tuple items refer to the index number. Use the
# index operator [ ] to access an item in a tuple. The index must be an integer.

# Creating a Set
# Set is an unordered collection of data type that is iterable, mutable and has
# no duplicate elements. The order of elements in a set is undefined though it
# may consist of various elements.
# Creating Sets
# Sets can be created by using the built-in set() function with an iterable object or a
# sequence by placing the sequence inside curly braces, separated by ‘comma’. Type
# of elements in a set need not be the same, various mixed-up data type values can also
# be passed to the set.
scale_set = set(["Suspès", "Aprovat", "Notable", "Excel·lent"])
# Set items cannot be accessed by referring to an index, since sets are unordered
# the items has no index. But you can loop through the set items using a for loop,
# or ask if a specified value is present in a set, by using the in keyword.
# Accessing elements of Sets
# Accessing element using for loop 
# print("\n Elements of set: ") 
# for i in scale_set: 
#    print("\n",i, end =" ")
    
# Checking the element using in keyword 
# print("\n Checking if the element exist : ", "Aprovat" in scale_set)

# Dictionary
# Dictionary in Python is an unordered collection of data values, used to store data
# values like a map, which unlike other Data Types that hold only single value as an
# element, Dictionary holds key:value pair. Key-value is provided in the dictionary
# to make it more optimized. Each key-value pair in a Dictionary is separated by a
# colon :, whereas each key is separated by a ‘comma’.
# Creating Dictionary
# In Python, a Dictionary can be created by placing a sequence of elements within
# curly {} braces, separated by ‘comma’. Values in a dictionary can be of any datatype
# and can be duplicated, whereas keys can’t be repeated and must be immutable.
# Dictionary can also be created by the built-in function dict(). An empty dictionary
# can be created by just placing it to curly braces{}.
scale_dict = {
  0 : "Suspès",
  1 : "Aprovat",
  2 : "Notable",
  3 : "Excel·lent"
}
# Accessing elements of Dictionary
# In order to access the items of a dictionary refer to its key name. Key can be used
# inside square brackets. There is also a method called get() that will also help in
# accessing the element from a dictionary.
#print("\n Accessing a value using key:", scale_dict[data_key])
#print("\n Accessing a value using get() method :", scale_dict.get(data_key))
#print("\n Accessing the keys", scale_dict.keys())
#print("\n Accessing the values", scale_dict.values())
#print("\n Accessing the items", scale_dict.items())

print("\n The classification labels are : ")
print(scale_tuple)

container_set = set(["List","Tuple","Dictionary"])
print("\n The containers of data are : ")
print(container_set)

constant.LIMIT_NUM = 10

# take input from user
#LIMIT_NUM = int(input("Enter the maximum limit of the classification scale : "))
print("\n The maximum limit of scale is :", constant.LIMIT_NUM)

input_value = int(input("Enter the value to classify [1-10] : "))
print("\n The value to classify is :", input_value)
#if LIMIT_NUM <= 0 or LIMIT_NUM > 100 :
#    break
#elif input_value <= 0 or input_value > 100 :
#    break
#break

# print data type
#print(type(input_value))

# type cast into integer
#input_value = int(input_value)

# Calculate the ranking
scale_div = len(scale_list)
#print(scale_div)
scale_num = constant.LIMIT_NUM / scale_div
#print(scale_num)

# Classification labeling
if input_value <= scale_num :
    idx = 0   # Suspès 
elif input_value <= 2 * scale_num :
    idx = 1   # Aprovat
elif input_value <= 3 * scale_num :
    idx = 2   # Notable
else:
    idx = 3   # Excel·lent

# Take input from user
# Enter the container number
data_type = int(input("Choose a container number: List [0], Tuple [1], Dictionary [2]"))
# type cast into integer
#data_type = int(data_type)
# print(data_type)
 
# Function to convert number into string
# switcher is dictionary data type here
def selector(argument):
    switcher = {
        0 :"List",
        1 :"Tuple",
        2 :"Dictionary"
    }
    # get() method of dictionary data type returns value of passed
    # argument if it is present in dictionary otherwise second argument
    # will be assigned as default value of passed argument
    # Get the function from switcher dictionary
    return switcher.get(argument, lambda: "Invalid Data Type")

# Execute the function
container = selector(data_type)
print("\n The data container choosed is : ", container)

# Print the classification
if data_type == 0 :
    print("\n The classification is : ", scale_list[idx]);    # list
elif data_type == 1 :
    print("\n The classification is : ",scale_tuple[idx]);    # tuple
elif data_type == 2 :
    print("\n The classification is : ", scale_dict[idx]);    # Dictionary

# %% [markdown]
# * Exercici 2 :
# Utilitzant el següent tutorial Programiz: Python Input, Output and Import crea un programa que et pregunti dos números. T’ha de mostrar un missatge dient si el primer és més gran, el segon és més gran o són iguals.

# %%
import math
import datetime

today = datetime.datetime.now()
#import sys
#print(sys.path)
#print(sys.prefix)

import getpass
username = getpass.getuser()
#print(username)

#import os.path
#homedir = os.path.expanduser("~")
#print(homedir)

#import os
#homedir = os.environ["HOME"]
#homedir = os.getenv("HOME")
#print(homedir)
#'HOME' in os.environ
#print(os.environ.get('HOME', '/home/username/'))
#print(os.environ.get('KEY_THAT_MIGHT_EXIST'))

#import socket
#hostname = socket.gethostname()
#print(hostname)

# The actual syntax of the print() function is:
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
# Here, objects is the value(s) to be printed.
# The sep separator is used between the values. It defaults into a space character.
# After all values are printed, end is printed. It defaults into a new line.
# The file is the object where the values are printed and its default value is
# sys.stdout (screen). 

print("".center(80, "*"))
print("\n")
print("I T   A C A D E M Y".center(80, " "))
print("\n")
print("Program to find the maximum among the given numbers".center(80, " "))
print("\n")
#print(today)
# prints the official format of date-time object
#print(type(repr(today)))
#print(repr(today))
# The width specifies the length of the returned string from zfill()
# with 0 digits filled to the left.

day_str = today.strftime("%A") # Day
month_str = today.strftime("%B") # Month
year_str = today.strftime("%Y") # Year
#year_str = today.year # Year

date_str = today.strftime("%x") # Date
time_str = today.strftime("%X") # Time

#print('Date : {date}'.ljust(80, " ").format(date = today.strftime("%x")),'Time : {time}'.rjust(80, " ").format(time = today.strftime("%X")))

print('Date : {date}'.ljust(62, " ").format(date = today.strftime("%x")),'Time : {time}'.format(time = today.strftime("%X")))
print("\n")
#print("Date : {:>2}".ljust(80, " ").format(date_str))
#print("Time : {:<35}".rjust(78, " ").format(time_str))
print("Author : {author}".center(70," ").format(author = "M. Augusto Maidana"))
print("\n")
print("".center(80, "*"))

nick_name = input("Enter your nickname or pulse 'Enter' : ")
#print("Great, you successfully entered your nickname!", nick_name)

print("\n")
# Left aligned
#print('My name is {:<25}'.format(nick_name))
# Right aligned
#print('My name is {:>25}'.format(nick_name))
# Centered
#print('My name is {:^25}'.format(nick_name))

if nick_name != "" : username = nick_name 

print('Hello {name}, {greeting}'.format(greeting = 'Good morning !!', name = username))
# Take input from user and cast into float
#input_val1, input_val2 = float(input("Enter two values : ")).split()
"""
valid = []
i=0
while True:
    try:
        if i==0 :
            num = float(input("Enter the first value: "))
        elif i==1 :
            num = float(input("Enter the second value: "))
        i += 1
        valid.append(num)
        if len(valid) == 2:
            break
    except ValueError:
        print("You need float!")
input_val1, input_val2 = valid
"""
val = {}
keys = ['first', 'second']
while True:
    try:
        for key in keys:
            val[key] = float(input(("Enter the ")+key+(" value : ")))
        if val['second'] != 0 :
            break
    except ValueError as err3:
        # Print custom error message
        print("Oops ! wrong input {0}, you must enter a numeric value. Try again...".format(err3))
        #raise
input_val1, input_val2 = val.values()
print(input_val1, input_val2)
#print("Great, you successfully entered two values!")
#print("The entered values are: ", input_val1, input_val2)

# type cast into float
#input_val1 = float(input_val1)
#input_val2 = float(input_val2)
# taking two input at a time
#input_val1, input_val2 = [float(x) for x in input("Enter two positive or negative numbers  separated by space : ").split()]

print('\nThe entered first value is : %3.1f' %input_val1)
print('\nThe entered second value is : %3.1f' %input_val2)
# sign '+' is for both positive and negative number
#print('{:+f}; {:+f}'.format(positive_number, negative_number))
# sign '-' is only for negative number
#print('{:f}; {:-f}'.format(positive_number, negative_number))
# taking multiple inputs at a time
# and type casting using list() function
#input_list = list(map(int, input("Enter a multiple value: ").split()))

print('\nThe maximum value between the given numbers {:3.1f} and {:3.1f} was computed by the function max(x,y)'.format(input_val1,input_val2))

#print(input_val1, input_val2, sep=' and ', end=' values')

# Python max()
# The Python max() function returns the largest item in an iterable.
# It can also be used to find the largest item between two or more parameters.
# To find the largest item in an iterable
# max(iterable, *iterables, key, default)

# To find the largest item between two or more objects
# max(arg1, arg2, *args, key)

largest_number = max(input_val1, input_val2)
print('\nThe largest number found is : %3.1f' %largest_number)

# padding of leading zeros of a character string
#number = "-290"
#print(number.zfill(8))

#number = "+290"
#print(number.zfill(8))

#text = "--random+text"
#print(text.zfill(20))

# Maximum in dictionaries

#square = {2: 4, -3: 9, -1: 1, -2: 4}

# the largest key
#key1 = max(square)
#print("The largest key:", key1)    # 2

# the key whose value is the largest
#key2 = max(square, key = lambda k: square[k])

#print("The key with the largest value:", key2)    # -3

# getting the largest value
#print("The largest value:", square[key2])    # 9

# %% [markdown]
# * Exercici 3 :
# Crea un programa que et pregunti el teu nom, i et demani un número. Si el número és 0, hauria de mostrar un missatge d’error. En cas contrari, hauria de mostrar el nom repetit tants cops com indiqui el número. Per exemple, “Joan Joan Joan”.

# %%
# This program asks for your name and age and prints it :
while True:
    try:
        # Take any data as a string
        name = input("Enter your name: \n")
        # Take any numeric data
        age = int(input("Enter your age: \n"))
        if age == 0:
            print("You must to type a number different of {null} as your age, try again !".format(null = age))
        else:
            print(age * (name + ' '))
            break

        # handle input errors

    except (ValueError):
        # Print custom error message
        print("Wrong input! You have to type a number as your age, try again !")
# Print the formatted data with name and age
print("Hello %s, You are %s years old." %(name, age))

# %% [markdown]
# * Exercici 4 :
# Crea un programa que donada una llista qualsevol, et digui si es simètrica o no. Si ho és, que et digui quants elements té.

# %%
# Function which return reverse of a list

# vowels list
# Symmetrical list
list1 = ['a', 'e', 'i', 'i', 'e', 'a']
# Non-symmetric list
list2 = ['a', 'e', 'i', 'o', 'i', 'u']

# Numerical list

# Symmetrical list
list3 = [1, 2, 3, 4, 3, 2, 1]

# Non-symmetric list
list4 = [3, 4, 2, 0, 2, 3, 6]

# String
# palindrome word
list5 = ["Neuquen"]

# no-palindrome word
list6 = ['Augusto']

#print(list1[::-1])

container = [list1, list2, list3, list4, list5, list6]

#print(*container)

def isPalindrome(llist):
    # check if x is a regular string
    if len(llist) == 1 and type(llist[0]) == str :
        print("The original list is : ", list1)
        #to change it the string is similar case
        llist = llist[0].lower()
        print("The lowercase string is : ", llist)
        return [llist == llist[::-1], len(llist)]
    # Print llist
    print("The list is : ", llist)
    return [llist == llist[::-1], len(llist)]
 
# Driver code

for list1 in container :
    ans = isPalindrome(list1)

    if ans[0]:
        print("The length of the list is : {0}".format(ans[1]))
        print("Yes, the list is symmetrical\n")
    else:
        print("No, the list is non-symmetric\n")

# %% [markdown]
# * Exercici 5 :
# Crea un programa que donada una llista, et digui quants números coincideixen amb la seva posició. Per exemple [3,4,2,0,2,3,6] el 2 i el 6 coincideixen.

# %%
#
# # The function returns a list with the numbers that match the index of its position
#

import random

# Numerical list of integers
# Non-symmetric list
#list1 = [3, 4, 2, 0, 2, 3, 6]

# Enter the length of the list
x = int(input("Enter the numbers of elements : "))
print("The length of the list is : ", x)

j = 1
# Iterating using while loop
while j <= 5 :
    print("\n")
    print(" Computing {counter}/5 times ".center(80,"*").format(counter = j))


    list1 = []
    # Set a length of the list to x
    for i in range(0, int(x)):
        # any random numbers from 0 to x
        list1.append(random.randint(0, x+1))

    print("\nThe list of elements is : ", list1)

    results = []
    i = 0
    for i in range(len(list1)):
        #print("The position indices is : ", i, list1[i])
        if i == list1[i]:
            results.append(list1[i])
    print("\nList of numbers that match the index of your position : ", results)

    # Another more compact alternative :

    # We are first zipping both the lists with zip. So, on every iteration, we will get           # elements # at corresponding positions from both the lists. And then we run it with          # enumerate which will return a tuple with the index and the actual element from the
    # iterable. We retain the # index, if the elements match.
    print("\nMore compact alternative : ")
    list2, idxs = list1, [*range(0, len(list1), 1)]
    print("\nList of numbers that match the index of your position : ",[index for index, (e1, e2) in enumerate(zip(list2, idxs)) if e1 == e2])

    # Counter of computing times
    j += 1
